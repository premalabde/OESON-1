# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set(color_codes=True)

# %%
MSFT = pd.read_csv('MSFT.csv')

# %%
MSFT.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  02/01/2018  86.129997  86.309998  85.500000  85.949997  80.940384
# 1  03/01/2018  86.059998  86.510002  85.970001  86.349998  81.317093
# 2  04/01/2018  86.589996  87.660004  86.570000  87.110001  82.032776
# 3  05/01/2018  87.660004  88.410004  87.430000  88.190002  83.049843
# 4  08/01/2018  88.199997  88.580002  87.599998  88.279999  83.134590
#
#      Volume   %change
# 0  22483800       NaN
# 1  26061400 -0.081271
# 2  21912000  0.006158
# 3  23407100  0.012357
# 4  22113000  0.006160

# %%
MSFT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1278 entries, 0 to 1277
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1278 non-null   object
#  1   Open       1278 non-null   float64
#  2   High       1278 non-null   float64
#  3   Low        1278 non-null   float64
#  4   Close      1278 non-null   float64
#  5   Adj Close  1278 non-null   float64
#  6   Volume     1278 non-null   int64
#  7   %change    1277 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 80.0+ KB

# %%
sns.barplot(MSFT['Date'], MSFT['%change'])
# Out:
# C:\Users\Rajesh - PC\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Date', ylabel='%change'>

# %%
sns.distplot(MSFT['%change'])
# Out:
# C:\Users\Rajesh - PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='%change', ylabel='Density'>

# %%
sns.pairplot(MSFT[['Open','High','%change']])

# %%
MSFT.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1278.000000  1278.000000  1278.000000  1278.000000  1278.000000
# mean    194.470900   196.522676   192.301847   194.510548   190.826784
# std      74.232396    75.002651    73.399757    74.241931    75.188361
# min      86.059998    86.309998    83.830002    85.010002    80.055191
# 25%     120.209999   120.827499   119.412503   120.197502   115.679996
# 50%     203.580002   205.190002   201.315002   203.050003   198.824714
# 75%     255.482506   257.789994   252.340000   254.207501   252.505246
# max     344.619995   349.670013   342.200012   343.109985   339.924805
#
#              Volume      %change
# count  1.278000e+03  1277.000000
# mean   3.026779e+07     0.000917
# std    1.284702e+07     0.018163
# min    8.989200e+06    -0.084075
# 25%    2.221248e+07    -0.008223
# 50%    2.706270e+07     0.001227
# 75%    3.437208e+07     0.011060
# max    1.112421e+08     0.084640

# %%
sns.pointplot(MSFT['Open'],MSFT['Low'],MSFT['%change'])

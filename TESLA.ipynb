# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pp
import seaborn as sns
sns.set(color_codes=True)

# %%
TESLA = pd.read_csv('TESLA.csv')

# %%
TESLA.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  02/01/2018  20.799999  21.474001  20.733334  21.368668  21.368668
# 1  03/01/2018  21.400000  21.683332  21.036667  21.150000  21.150000
# 2  04/01/2018  20.858000  21.236668  20.378668  20.974667  20.974667
# 3  05/01/2018  21.108000  21.149332  20.799999  21.105333  21.105333
# 4  08/01/2018  21.066668  22.468000  21.033333  22.427334  22.427334
#
#       Volume   %change
# 0   65283000       NaN
# 1   67822500  0.028846
# 2  149194500 -0.025327
# 3   68868000  0.011986
# 4  147891000 -0.001958

# %%
TESLA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1278 entries, 0 to 1277
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1278 non-null   object
#  1   Open       1278 non-null   float64
#  2   High       1278 non-null   float64
#  3   Low        1278 non-null   float64
#  4   Close      1278 non-null   float64
#  5   Adj Close  1278 non-null   float64
#  6   Volume     1278 non-null   int64
#  7   %change    1277 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 80.0+ KB

# %%
sns.barplot(TESLA['Date'], TESLA['%change'])
# Out:
# C:\Users\Rajesh - PC\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Date', ylabel='%change'>

# %%
TESLA.TESLA('%Change').Min()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11396\704649425.py in <module>
# ----> 1 TESLA.TESLA('%Change').Min()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'TESLA'

# %%
TESLA.TESLA('%Change').Max()

# %%
sns.distplot(TESLA['%change'])

# %%
sns.pairplot(TESLA[['Open','High','%change']])

# %%
TESLA.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1278.000000  1278.000000  1278.000000  1278.000000  1278.000000
# mean    131.895211   134.958406   128.511830   131.790281   131.790281
# std     117.166580   119.816919   114.137511   116.978976   116.978976
# min      12.073333    12.445333    11.799333    11.931333    11.931333
# 25%      21.088166    21.509167    20.684500    21.148001    21.148001
# 50%      96.573334   100.321666    94.266998    97.640004    97.640004
# 75%     234.916672   239.542503   229.159164   235.380832   235.380832
# max     411.470001   414.496674   405.666656   409.970001   409.970001
#
#              Volume      %change
# count  1.278000e+03  1277.000000
# mean   1.333573e+08     0.002625
# std    8.993084e+07     0.043617
# min    2.940180e+07    -0.210924
# 25%    7.605360e+07    -0.021443
# 50%    1.031696e+08     0.001982
# 75%    1.579424e+08     0.023601
# max    9.140820e+08     0.310632

# %%
sns.pointplot(TESLA['Open'],TESLA['Low'],TESLA['%change'])

# %%
sns.lmplot(x='Open',y='%Change',data=TESLA)
